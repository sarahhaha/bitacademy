# %%
from tkinter import *
from tkinter import ttk

length_list = [('Measurements of Length','cm','meter', 'inch', 'feet', 'yard', 'mile'),
               ('cm', 1, 0.01,0.3937,0.0328,0.0109,6.21371e-6),
              ('meter', 100, 1, 39.37, 3.2808, 1.0936, 0.0006),
              ('inch',2.54,0.0245,1,0.0833,0.0278,1.57828e-5),
              ('feet',30.48,0.3048,12,1,0.3333,0.00019),
              ('yard',91.438,0.9144,36,3,1,0.0006),
              ('mile',160930,1609.3,63360,5280,1760,1)]

weight_list = [('Measurements of Weight','gram','kilogram','ton','grain','ounce','pound'),
               ('gram', 1,0.001,0.000001,15.432,0.03527,0.0022),
              ('kilogram',1000,1,0.001,15432,35.273,2.20459),
              ('ton',1000000,1000,1,1.4E7,35273,2204.59),
              ('grain',0.06479,0.00006,7.13286e-8,1,0.00228,0.00014),
              ('ounce',28.3495,0.02835,0.000028,43.7,1,0.0625),
              ('pound',453.592,0.45359,0.00045,7000,16,1)]

area_list = [('Measurements of Area','square meter','are','square feet','square yard','acre'),
            ('square meter',1,0.01,10.764,1.1958,0.00024),
            ('are',100,1,1076.4,119.58,0.02471),
            ('square feet',0.092903,0.000929,1,0.1111,0.000022),
            ('square yard',0.83613,0.00836,9,1,0.000207),
            ('acre',4046.8,40.468,43560,4840,1)]

lrows = len(length_list)
lcolumns = len(length_list[0])
wrows = len(weight_list)
wcolumns = len(weight_list[0])
arows = len(area_list)
acolumns = len(area_list[0])

root = Tk()

def lengthbox(parent,rows,columns):
    for i in range(rows):
        for j in range(columns):
            Label(parent, text = length_list[i][j]).grid(row = i, column = j)
    
def weightbox(parent,rows,columns):
    for i in range(rows):
        for j in range(columns):
            Label(parent, text = weight_list[i][j]).grid(row = i, column = j)


def areabox(parent,rows,columns):
    for i in range(rows):
        for j in range(columns):
            Label(parent, text = area_list[i][j]).grid(row = i, column = j)

"""
changedlength = [('cm: ',1),
                ('meter: ',1),
                ('inch: ',1),
                ('feet: ',1),
                ('yard:',1),
                ('mile: ',1)]
"""

def button1():
    print('ok')
    lenselect = lenselects.get()
    inputlength = inputleng.get()
    inputlen = int(inputlength)
    if lenselect == 'cm':
        print('cm')
        print(inputlen)
        calccm = inputlen * length_list[1][1]
        calcmeter = inputlen * length_list[1][2]
        calcinch = inputlen * length_list[1][3]
        calcfeet = inputlen * length_list[1][4]
        calcyard = inputlen * length_list[1][5]
        calcmile = inputlen * length_list[1][6]
    elif lenselect == 'meter':
        calccm = inputlen * length_list[2][1]
        calcmeter = inputlen * length_list[2][2]
        calcinch = inputlen * length_list[2][3]
        calcfeet = inputlen * length_list[2][4]
        calcyard = inputlen * length_list[2][5]
        calcmile = inputlen * length_list[2][6]
    elif lenselect == 'inch':
        calccm = inputlen * length_list[3][1]
        calcmeter = inputlen * length_list[3][2]
        calcinch = inputlen * length_list[3][3]
        calcfeet = inputlen * length_list[3][4]
        calcyard = inputlen * length_list[3][5]
        calcmile = inputlen * length_list[3][6]
    elif lenselect == 'feet':
        calccm = inputlen * length_list[4][1]
        calcmeter = inputlen * length_list[4][2]
        calcinch = inputlen * length_list[4][3]
        calcfeet = inputlen * length_list[4][4]
        calcyard = inputlen * length_list[4][5]
        calcmile = inputlen * length_list[4][6]
    elif lenselect == 'yard':
        calccm = inputlen * length_list[5][1]
        calcmeter = inputlen * length_list[5][2]
        calcinch = inputlen * length_list[5][3]
        calcfeet = inputlen * length_list[5][4]
        calcyard = inputlen * length_list[5][5]
        calcmile = inputlen * length_list[5][6]
    elif lenselect == 'mile':
        calccm = inputlen * length_list[6][1]
        calcmeter = inputlen * length_list[6][2]
        calcinch = inputlen * length_list[6][3]
        calcfeet = inputlen * length_list[6][4]
        calcyard = inputlen * length_list[6][5]
        calcmile = inputlen * length_list[6][6]
    else:
        calccm = 0
        calcmeter = 0
        calcinch = 0
        calcfeet = 0
        calcyard = 0
        calcmile = 0
    changedlength = [('cm: ',calccm),
                ('meter: ',calcmeter),
                ('inch: ',calcinch),
                ('feet: ',calcfeet),
                ('yard:',calcyard),
                ('mile: ',calcmile)]
    _frame = Frame(root)
    _frame.pack()
    lengthresult(_frame,changedlength)
    
            


Label(root, text = 'Select length and measurement of length: ').pack()
inputleng = Entry(root)
inputleng.pack()
lenselects = ttk.Combobox(root,values = ['cm','meter', 'inch', 'feet', 'yard', 'mile'])
lenselects.pack()


def lengthresult(parent,lst):
    for i, row in enumerate(lst):
        print(i)
        print(row)
        value = row[0]+str(row[1])
        Labels[i].config(text = value)
        Labels[i].update_idletasks()

Button(root, text = 'Go', command = button1).pack()


_frame = Frame(root)
_frame.pack()
lengthbox(_frame,lrows,lcolumns)

Label(root, text = 'Select weight and measurement of weight: ').pack()
inputweig = Entry(root)
inputweig.pack()
weiselects = ttk.Combobox(root,values = ['gram','kilogram','ton','grain','ounce','pound'])
weiselects.pack()

def button2():
    print('ok')
    weiselect = weiselects.get()
    inputweigh = inputweig.get()
    inputwei = int(inputweigh)
    if weiselect == 'gram':
        print('gram')
        print(inputwei)
        calcgram = inputwei * weight_list[1][1]
        calckilogram = inputwei * weight_list[1][2]
        calcton = inputwei * weight_list[1][3]
        calcgrain = inputwei * weight_list[1][4]
        calcounce = inputwei * weight_list[1][5]
        calcpound = inputwei * weight_list[1][6]
    elif weiselect == 'kilogram':
        calcgram = inputwei * weight_list[2][1]
        calckilogram = inputwei * weight_list[2][2]
        calcton = inputwei * weight_list[2][3]
        calcgrain = inputwei * weight_list[2][4]
        calcounce = inputwei * weight_list[2][5]
        calcpound = inputwei * weight_list[2][6]
    elif weiselect == 'ton':
        calcgram = inputwei * weight_list[3][1]
        calckilogram = inputwei * weight_list[3][2]
        calcton = inputwei * weight_list[3][3]
        calcgrain = inputwei * weight_list[3][4]
        calcounce = inputwei * weight_list[3][5]
        calcpound = inputwei * weight_list[3][6]
    elif weiselect == 'grain':
        calcgram = inputwei * weight_list[4][1]
        calckilogram = inputwei * weight_list[4][2]
        calcton = inputwei * weight_list[4][3]
        calcgrain = inputwei * weight_list[4][4]
        calcounce = inputwei * weight_list[4][5]
        calcpound = inputwei * weight_list[4][6]
    elif weiselect == 'ounce':
        calcgram = inputwei * weight_list[5][1]
        calckilogram = inputwei * weight_list[5][2]
        calcton = inputwei * weight_list[5][3]
        calcgrain = inputwei * weight_list[5][4]
        calcounce = inputwei * weight_list[5][5]
        calcpound = inputwei * weight_list[5][6]
    elif weiselect == 'mile':
        calcgram = inputwei * weight_list[6][1]
        calckilogram = inputwei * weight_list[6][2]
        calcton = inputwei * weight_list[6][3]
        calcgrain = inputwei * weight_list[6][4]
        calcounce = inputwei * weight_list[6][5]
        calcpound = inputwei * weight_list[6][6]
    else:
        calcgram = 0
        calckilogram = 0
        calcton = 0
        calcgrain = 0
        calcounce = 0
        calcpound = 0
    changedweight = [('gram: ',calcgram),
                ('kilogram: ',calckilogram),
                ('ton: ',calcton),
                ('grain: ',calcgrain),
                ('ounce:',calcounce),
                ('pound: ',calcpound)]
    _frame = Frame(root)
    _frame.pack()
    lengthresult(_frame,changedweight)
    
Button(root, text = 'Go', command = button2).pack()

_frame = Frame(root)
_frame.pack()
weightbox(_frame,wrows,wcolumns)

Label(root, text = 'Select area and measurement of area: ').pack()
inputarea = Entry(root)
inputarea.pack()
areselects = ttk.Combobox(root,values = ['square meter','are','square feet','square yard','acre'])
areselects.pack()

def button3():
    print('ok')
    areselect = areselects.get()
    inputareaa = inputarea.get()
    inputare = int(inputareaa)
    if areselect == 'square meter':
        print('square meter')
        print(inputare)
        calcsquaremeter = inputare * area_list[1][1]
        calcare = inputare * area_list[1][2]
        calcsquarefeet = inputare * area_list[1][3]
        calcsquareyard = inputare * area_list[1][4]
        calcacre = inputare * area_list[1][5]
    elif areselect == 'are':
        calcsquaremeter = inputare * area_list[2][1]
        calcare = inputare * area_list[2][2]
        calcsquarefeet = inputare * area_list[2][3]
        calcsquareyard = inputare * area_list[2][4]
        calcacre = inputare * area_list[2][5]
    elif areselect == 'square feet':
        calcsquaremeter = inputare * area_list[3][1]
        calcare = inputare * area_list[3][2]
        calcsquarefeet = inputare * area_list[3][3]
        calcsquareyard = inputare * area_list[3][4]
        calcacre = inputare * area_list[3][5]
    elif areselect == 'square yard':
        calcsquaremeter = inputare * area_list[4][1]
        calcare = inputare * area_list[4][2]
        calcsquarefeet = inputare *area_list[4][3]
        calcsquareyard = inputare * area_list[4][4]
        calcacre = inputare *area_list[4][5]
    elif areselect == 'acre':
        calcsquaremeter = inputare * area_list[5][1]
        calcare = inputare *area_list[5][2]
        calcsquarefeet = inputare *area_list[5][3]
        calcsquareyard = inputare *area_list[5][4]
        calcacre = inputare * area_list[5][5]
    else:
        calcsquaremeter = 0
        calcare = 0
        calcsquarefeet = 0
        calcsquareyard = 0
        calcacre = 0
    changedarea = [('square meter: ',calcsquaremeter),
                ('are: ',calcare),
                ('square feet: ',calcsquarefeet),
                ('square yard: ',calcsquareyard),
                ('acre:',calcacre)]
    _frame = Frame(root)
    _frame.pack()
    lengthresult(_frame,changedarea)

Button(root, text = 'Go', command = button3).pack()

_frame = Frame(root)
_frame.pack()
areabox(_frame,arows,acolumns)

Labels = []
for i in range(6):
    if i == 0:
        Label(root, text = 'results:').pack()
    Labels.append(Label(root, text = ''))
    Labels[i].pack()

mainloop()
